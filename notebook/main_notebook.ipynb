# %%
import pandas as pd

# Load the dataset
try:
    df = pd.read_csv('../data_raw/us-shein-sports_and_outdoors-3853.csv')
except ValueError:
    print("Unable to load the dataset into notebook")
except FileNotFoundError:
    print("Unable to find the file in that path")

# %%
# Show the head of dataset
df.head()
# Out:
#    color-count                            blackfridaybelts-bg src  \
# 0          5.0  https://img.ltwebstatic.com/images3_ccc/2023/1...
# 1          NaN                                                NaN
# 2          8.0                                                NaN
# 3         13.0  https://img.ltwebstatic.com/images3_ccc/2023/1...
# 4          NaN  https://img.ltwebstatic.com/images3_ccc/2023/1...
#
#   blackfridaybelts-content                             goods-title-link--jump  \
# 0               Save $5.24  3pcs/Set Women Seamless Yoga Shorts, High Wais...
# 1                      NaN  1 Pc Battery Operated Mini Portable Fan, Light...
# 2                      NaN  Sports Shoes, Street Sports Shoes, Men's And W...
# 3               Save $6.53  SHEIN Yoga Basic Seamless High Stretch Sports Set
# 4               Save $2.55  Tennis Basic Pleated Detail Sports Skort With ...
#
#                          goods-title-link--jump href       rank-title  \
# ...

# %%
# Show the sample from the dataset
df.sample(5)
# Out:
#       color-count                            blackfridaybelts-bg src  \
# 102           NaN                                                NaN
# 1121          NaN                                                NaN
# 3426          NaN  https://img.ltwebstatic.com/images3_ccc/2023/1...
# 628           4.0  https://img.ltwebstatic.com/images3_ccc/2023/1...
# 3020          NaN                                                NaN
#
#      blackfridaybelts-content goods-title-link--jump  \
# 102                       NaN                    NaN
# 1121                      NaN                    NaN
# 3426               Save $8.57                    NaN
# 628                Save $7.22                    NaN
# 3020                      NaN                    NaN
#
#      goods-title-link--jump href       rank-title  \
# 102                          NaN  #1 Best Sellers
# 1121                         NaN              NaN
# 3426                         NaN  #5 Best Sellers
# ...

# %%
# Check the shape of the dataset
df.shape
# Out:
# (3852, 11)

# %%
# Show the dataset columns
df.columns
# Out:
# Index(['color-count', 'blackfridaybelts-bg src', 'blackfridaybelts-content',
#        'goods-title-link--jump', 'goods-title-link--jump href', 'rank-title',
#        'rank-sub', 'price', 'discount', 'selling_proposition',
#        'goods-title-link'],
#       dtype='object')

# %%
# Check missing values
df.isnull().sum()
# Out:
# color-count                    2637
# blackfridaybelts-bg src        2281
# blackfridaybelts-content       2281
# goods-title-link--jump         3813
# goods-title-link--jump href    3813
# rank-title                     2666
# rank-sub                       2666
# price                             0
# discount                        627
# selling_proposition            1359
# goods-title-link                 39
# dtype: int64

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# np.int64(117)

# %%
# Drop duplicates
df.drop_duplicates(inplace=True)

# %%
# Apply the cleaning data function
import utils as ut

df_clean = ut.clean_dataset(df)

# %%
# Show the cleaned dataset
df_clean.head()
# Out:
#    price  discount  selling_proposition  \
# 0   7.85        40                    0
# 1   1.02        67                    0
# 2  88.70        24                    0
# 3   5.96        52                 3100
# 4   7.64        25                 8300
#
#                                        product_title  rank_number  \
# 0  3pcs/Set Women Seamless Yoga Shorts, High Wais...          9.0
# 1  1 Pc Battery Operated Mini Portable Fan, Light...          5.0
# 2  Sports Shoes, Street Sports Shoes, Men's And W...          1.0
# 3  SHEIN Yoga Basic Seamless High Stretch Sports Set          NaN
# 4  Tennis Basic Pleated Detail Sports Skort With ...          NaN
#
#       rank_type                    rank_category  is_ranked
# 0  Best Sellers              Women Sports Shorts          1
# 1  Best Sellers                 Camping & Hiking          1
# 2   Best Seller  In Black and White Men Sneakers          1
# 3           NaN                              NaN          0
# ...

# %%
# Show the sample from the cleaned dataset
df_clean.sample(5)
# Out:
#       price  discount  selling_proposition  \
# 2224  10.15        20                    0
# 903    3.30        13                  400
# 996    1.60         0                 1500
# 3828  14.00        25                    0
# 2460   7.17        30                  100
#
#                                           product_title  rank_number  \
# 2224  Shapewear For Women Tummy Control Fajas Post S...          5.0
# 903   2/3/4/5pcs Portable Mini Transparent Zipper St...          NaN
# 996   1/3/5 Pair Lifting Silicone Nipple Covers, Str...          NaN
# 3828                Men Ribbed Breathable Running Shoes          NaN
# 2460  1pc, 20oz Skinny Sublimation Tumbler, Stainles...          NaN
#
#          rank_type              rank_category  is_ranked
# 2224  Best Sellers  Women Shapewear Bodysuits          1
# 903            NaN                        NaN          0
# 996            NaN                        NaN          0
# ...

# %%
# Save the cleaned dataset
df_clean.to_csv('../data_cleaned/cleaned_shein_sports_and_outdoors.csv', index=False)
